# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %% [markdown]
# ## GTZAN

# %%
train_embeddings = np.load("gtzan/gtzan_train_embeddings.npy")
train_labels = np.load("gtzan/gtzan_train_labels.npy")
unique_labels, count_labels = np.unique(train_labels, return_counts=True)
print("Train label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Train label count:
#     - blues: 276
#     - classical: 288
#     - country: 270
#     - disco: 252
#     - hiphop: 282
#     - jazz: 252
#     - metal: 264
#     - pop: 246
#     - reggae: 258
#     - rock: 264

# %%
tsne_train_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(train_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_train_embeddings[train_labels == label, 0],
        tsne_train_embeddings[train_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
val_embeddings = np.load("gtzan/gtzan_val_embeddings.npy")
val_labels = np.load("gtzan/gtzan_val_labels.npy")
unique_labels, count_labels = np.unique(val_labels, return_counts=True)
print("Validation label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Validation label count:
#     - blues: 138
#     - classical: 120
#     - country: 138
#     - disco: 132
#     - hiphop: 108
#     - jazz: 102
#     - metal: 120
#     - pop: 78
#     - reggae: 102
#     - rock: 144

# %%
tsne_val_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(val_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_val_embeddings[val_labels == label, 0],
        tsne_val_embeddings[val_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
test_embeddings = np.load("gtzan/gtzan_test_embeddings.npy")
test_labels = np.load("gtzan/gtzan_test_labels.npy")
unique_labels, count_labels = np.unique(test_labels, return_counts=True)
print("Test label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Test label count:
#     - blues: 186
#     - classical: 186
#     - country: 180
#     - disco: 174
#     - hiphop: 162
#     - jazz: 162
#     - metal: 162
#     - pop: 180
#     - reggae: 156
#     - rock: 192

# %%
tsne_test_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(test_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_test_embeddings[test_labels == label, 0],
        tsne_test_embeddings[test_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# ## VocalSet - Singer

# %%
train_embeddings = np.load("vocalset-singer/vocalset-singer_train_embeddings.npy")
train_labels = np.load("vocalset-singer/vocalset-singer_train_labels.npy")
unique_labels, count_labels = np.unique(train_labels, return_counts=True)
print("Train label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Train label count:
#     - female1: 168
#     - female2: 197
#     - female3: 174
#     - female4: 108
#     - female5: 192
#     - female6: 134
#     - female7: 154
#     - female8: 184
#     - female9: 139
#     - male1: 183
#     - male10: 142
#     - male11: 127
#     - male2: 164
#     - male3: 191
#     - male4: 152
#     - male5: 161
#     - male6: 175
#     - male7: 164
#     - male8: 142
#     - male9: 149

# %%
tsne_train_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(train_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_train_embeddings[train_labels == label, 0],
        tsne_train_embeddings[train_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
val_embeddings = np.load("vocalset-singer/vocalset-singer_val_embeddings.npy")
val_labels = np.load("vocalset-singer/vocalset-singer_val_labels.npy")
unique_labels, count_labels = np.unique(val_labels, return_counts=True)
print("Validation label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Validation label count:
#     - female1: 119
#     - female2: 119
#     - female3: 112
#     - female4: 83
#     - female5: 114
#     - female6: 99
#     - female7: 107
#     - female8: 110
#     - female9: 88
#     - male1: 128
#     - male10: 88
#     - male11: 97
#     - male2: 106
#     - male3: 132
#     - male4: 94
#     - male5: 133
#     - male6: 129
#     - male7: 103
#     - male8: 103
#     - male9: 106

# %%
tsne_val_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(val_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_val_embeddings[val_labels == label, 0],
        tsne_val_embeddings[val_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
test_embeddings = np.load("vocalset-singer/vocalset-singer_test_embeddings.npy")
test_labels = np.load("vocalset-singer/vocalset-singer_test_labels.npy")
unique_labels, count_labels = np.unique(test_labels, return_counts=True)
print("Test label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Test label count:
#     - female1: 68
#     - female2: 92
#     - female3: 69
#     - female4: 46
#     - female5: 82
#     - female6: 58
#     - female7: 68
#     - female8: 69
#     - female9: 59
#     - male1: 83
#     - male10: 53
#     - male11: 66
#     - male2: 66
#     - male3: 73
#     - male4: 65
#     - male5: 75
#     - male6: 81
#     - male7: 83
#     - male8: 53
#     - male9: 68

# %%
tsne_test_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(test_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_test_embeddings[test_labels == label, 0],
        tsne_test_embeddings[test_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# ## VocalSet - Tech

# %%
train_embeddings = np.load("vocalset-tech/vocalset-tech_train_embeddings.npy")
train_labels = np.load("vocalset-tech/vocalset-tech_train_labels.npy")
unique_labels, count_labels = np.unique(train_labels, return_counts=True)
print("Train label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Train label count:
#     - belt: 187
#     - breathy: 202
#     - inhaled: 68
#     - lip_trill: 156
#     - spoken: 28
#     - straight: 492
#     - trill: 125
#     - trillo: 102
#     - vibrato: 406
#     - vocal_fry: 207

# %%
tsne_train_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(train_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_train_embeddings[train_labels == label, 0],
        tsne_train_embeddings[train_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
val_embeddings = np.load("vocalset-tech/vocalset-tech_val_embeddings.npy")
val_labels = np.load("vocalset-tech/vocalset-tech_val_labels.npy")
unique_labels, count_labels = np.unique(val_labels, return_counts=True)
print("Validation label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Validation label count:
#     - belt: 28
#     - breathy: 26
#     - inhaled: 11
#     - lip_trill: 20
#     - spoken: 4
#     - straight: 67
#     - trill: 24
#     - trillo: 14
#     - vibrato: 52
#     - vocal_fry: 25

# %%
tsne_val_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(val_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_val_embeddings[val_labels == label, 0],
        tsne_val_embeddings[val_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
test_embeddings = np.load("vocalset-tech/vocalset-tech_test_embeddings.npy")
test_labels = np.load("vocalset-tech/vocalset-tech_test_labels.npy")
unique_labels, count_labels = np.unique(test_labels, return_counts=True)
print("Test label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Test label count:
#     - belt: 67
#     - breathy: 70
#     - inhaled: 32
#     - lip_trill: 78
#     - spoken: 12
#     - straight: 230
#     - trill: 65
#     - trillo: 36
#     - vibrato: 176
#     - vocal_fry: 137

# %%
tsne_test_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(test_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_test_embeddings[test_labels == label, 0],
        tsne_test_embeddings[test_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# ## NSynth

# %%
train_embeddings = np.load("nsynth/nsynth_train_embeddings.npy")
train_labels = np.load("nsynth/nsynth_train_labels.npy")
unique_labels, count_labels = np.unique(train_labels, return_counts=True)
print(f"Train total elements: {len(train_embeddings)}")
print("Train label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Train total elements: 289205
# Train label count:
#     - bass: 65474
#     - brass: 12675
#     - flute: 8773
#     - guitar: 32690
#     - keyboard: 51821
#     - mallet: 34201
#     - organ: 34477
#     - reed: 13911
#     - string: 19474
#     - synth_lead: 5501
#     - vocal: 10208

# %%
tsne_train_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=30.0
).fit_transform(train_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_train_embeddings[train_labels == label, 0],
        tsne_train_embeddings[train_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
val_embeddings = np.load("nsynth/nsynth_val_embeddings.npy")
val_labels = np.load("nsynth/nsynth_val_labels.npy")
unique_labels, count_labels = np.unique(val_labels, return_counts=True)
print("Validation label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Validation label count:
#     - bass: 2638
#     - brass: 886
#     - flute: 470
#     - guitar: 2081
#     - keyboard: 2404
#     - mallet: 663
#     - organ: 1598
#     - reed: 720
#     - string: 814
#     - vocal: 404

# %%
tsne_val_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=3
).fit_transform(val_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_val_embeddings[val_labels == label, 0],
        tsne_val_embeddings[val_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()

# %%
test_embeddings = np.load("nsynth/nsynth_test_embeddings.npy")
test_labels = np.load("nsynth/nsynth_test_labels.npy")
unique_labels, count_labels = np.unique(test_labels, return_counts=True)
print("Test label count:")
for label, count in zip(unique_labels, count_labels):
    print(f"    - {label}: {count}")
# Out:
# Test label count:
#     - bass: 843
#     - brass: 269
#     - flute: 180
#     - guitar: 652
#     - keyboard: 766
#     - mallet: 202
#     - organ: 502
#     - reed: 235
#     - string: 306
#     - vocal: 141

# %%
tsne_test_embeddings = TSNE(
    n_components=2, learning_rate="auto", init="random", perplexity=3
).fit_transform(test_embeddings)

# %%
fig, ax = plt.subplots()
for label in unique_labels:
    ax.scatter(
        tsne_test_embeddings[test_labels == label, 0],
        tsne_test_embeddings[test_labels == label, 1],
        s=6.0,
        label=label,
        edgecolors="none",
    )

ax.legend()
ax.grid(True)

plt.show()
